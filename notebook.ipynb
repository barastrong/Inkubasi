# %% [markdown]
# ### Kelas Inkubasi
# # Business Data Analytics
# SMK Telkom x WPC x BeData Technology

# %% [markdown]
# ### Business Understanding : merumuskan pertanyaan bisnis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Problem :
# Bayangkan Anda adalah seorang analis data untuk "Chinook," sebuah toko musik digital. Model bisnis Chinook adalah menjual trek musik digital kepada pelanggan di seluruh dunia. Manajemen senior datang kepada Anda dengan tujuan yang sangat umum: ***"Kami ingin meningkatkan pendapatan dan memahami pelanggan kami dengan lebih baik."***
# Tujuan ini, meskipun penting, terlalu luas untuk dianalisis secara langsung. Tugas Anda adalah memecah tujuan ini menjadi serangkaian pertanyaan bisnis yang spesifik, terukur, dan dapat dijawab menggunakan data yang tersedia dalam basis data perusahaan. Skema basis data adalah peta Anda untuk memahami aset data yang dimiliki.

# %% [markdown]
# ##### Questions:
# 1. Siapa 10 pelanggan dengan total pembelian tertinggi yang secara konsisten menyumbang minimal 20% dari total revenue perusahaan, dan berasal dari 3 negara dengan kontribusi penjualan terbesar, selama periode Januari 2023 hingga Desember 2024?
# 2. Dalam upaya mencapai target peningkatan pendapatan, dapatkah kita menganalisis total pendapatan yang dihasilkan oleh lima genre musik teratas dan lima artis terlaris secara triwulanan selama dua tahun fiskal terakhir, dan apakah data ini dapat mengungkap adanya tren musiman atau pergeseran preferensi pelanggan yang dapat kita manfaatkan untuk memfokuskan promosi yang ditargetkan?
# 3. Kota/negara mana yang paling banyak ditangani tiap Support Rep?

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
load_dotenv()
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
HOST = os.getenv("HOST")
USER = os.getenv("USER")
PASSWORD = os.getenv("PASSWORD")
PORT = os.getenv("PORT")
DB_NAME = os.getenv("DB_NAME")
# SSL_MODE = os.getenv("SSL_MODE")

# %%
SERVICE_URI = f"postgres://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}"
uri = SERVICE_URI.replace("postgres://", "postgresql+psycopg2://", 1)
engine = create_engine(uri)

# %% [markdown]
# #### customer

# %%
df_customer = pd.read_sql(
    '''SELECT * 
    FROM customer'''
, con=engine)
df_customer.head()
# Out:
#    customer_id first_name    last_name  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            address                 city state         country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# 4                    Klanova 9/506               Prague  None  Czech Republic
#
#   postal_code               phone                 fax  \
# 0   12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1       70174    +49 0711 2842222                None
# 2     H2G 1A7   +1 (514) 721-4711                None
# 3        0171     +47 22 44 22 22                None
# 4       14700    +420 2 4172 5555    +420 2 4172 5555
#
#                       email  support_rep_id
# 0      luisg@embraer.com.br               3
# 1     leonekohler@surfeu.de               5
# 2       ftremblay@gmail.com               3
# 3     bjorn.hansen@yahoo.no               4
# 4  frantisekw@jetbrains.com               4

# %% [markdown]
# #### invoice

# %%
df_invoice = pd.read_sql(
    '''SELECT * 
    FROM invoice'''
, con=engine)
df_invoice.head()
# Out:
#    invoice_id  customer_id invoice_date          billing_address billing_city  \
# 0           1            2   2021-01-01  Theodor-Heuss-Straße 34    Stuttgart
# 1           2            4   2021-01-02         Ullevålsveien 14         Oslo
# 2           3            8   2021-01-03          Grétrystraat 63     Brussels
# 3           4           14   2021-01-06           8210 111 ST NW     Edmonton
# 4           5           23   2021-01-11          69 Salem Street       Boston
#
#   billing_state billing_country billing_postal_code  total
# 0          None         Germany               70174   1.98
# 1          None          Norway                0171   3.96
# 2          None         Belgium                1000   5.94
# 3            AB          Canada             T6G 2C7   8.91
# 4            MA             USA                2113  13.86

# %% [markdown]
# #### invoice line

# %%
df_invoice_line = pd.read_sql(
    '''SELECT * 
    FROM invoice_line'''
, con=engine)
df_invoice_line.head()
# Out:
#    invoice_line_id  invoice_id  track_id  unit_price  quantity
# 0                1           1         2        0.99         1
# 1                2           1         4        0.99         1
# 2                3           2         6        0.99         1
# 3                4           2         8        0.99         1
# 4                5           2        10        0.99         1

# %% [markdown]
# #### track

# %%
df_track = pd.read_sql(
    '''SELECT *
    FROM track'''
    , con=engine)
df_track
# Out:
#       track_id                                               name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price
# 0     11170334        0.99
# 1      5510424        0.99
# 2      3990994        0.99
# 3      4331779        0.99
# 4      6290521        0.99
# ...        ...         ...
# 3498   4718950        0.99
# 3499   2283131        0.99
# 3500   1189062        0.99
# 3501   3665114        0.99
# 3502   3305164        0.99
#
# [3503 rows x 9 columns]

# %% [markdown]
# #### genre

# %%
df_genre = pd.read_sql(
    '''
    SELECT *
    FROM genre
    ''', con=engine
)
df_genre
# Out:
#     genre_id                name
# 0          1                Rock
# 1          2                Jazz
# 2          3               Metal
# 3          4  Alternative & Punk
# 4          5       Rock And Roll
# 5          6               Blues
# 6          7               Latin
# 7          8              Reggae
# 8          9                 Pop
# 9         10          Soundtrack
# 10        11          Bossa Nova
# 11        12      Easy Listening
# 12        13         Heavy Metal
# 13        14            R&B/Soul
# 14        15   Electronica/Dance
# 15        16               World
# 16        17         Hip Hop/Rap
# 17        18     Science Fiction
# 18        19            TV Shows
# 19        20    Sci Fi & Fantasy
# 20        21               Drama
# 21        22              Comedy
# 22        23         Alternative
# 23        24           Classical
# 24        25               Opera

# %% [markdown]
# #### album

# %%
df_album = pd.read_sql(
    '''
    SELECT *
    FROM album
    ''', con=engine
)
df_album
# Out:
#      album_id                                              title  artist_id
# 0           1              For Those About To Rock We Salute You          1
# 1           2                                  Balls to the Wall          2
# 2           3                                  Restless and Wild          2
# 3           4                                  Let There Be Rock          1
# 4           5                                           Big Ones          3
# ..        ...                                                ...        ...
# 342       343                             Respighi:Pines of Rome        226
# 343       344  Schubert: The Late String Quartets & String Qu...        272
# 344       345                                Monteverdi: L'Orfeo        273
# 345       346                              Mozart: Chamber Music        274
# 346       347  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
# [347 rows x 3 columns]

# %% [markdown]
# #### artist

# %%
df_artist = pd.read_sql(
    '''
    SELECT *
    FROM artist
    ''', con=engine
)
df_artist
# Out:
#      artist_id                                               name
# 0            1                                              AC/DC
# 1            2                                             Accept
# 2            3                                          Aerosmith
# 3            4                                  Alanis Morissette
# 4            5                                    Alice In Chains
# ..         ...                                                ...
# 270        271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271        272                             Emerson String Quartet
# 272        273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273        274                                      Nash Ensemble
# 274        275                              Philip Glass Ensemble
#
# [275 rows x 2 columns]

# %% [markdown]
# ### Assessing & Cleaning

# %% [markdown]
# #### customer

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     59 non-null     int64
#  1   first_name      59 non-null     object
#  2   last_name       59 non-null     object
#  3   company         10 non-null     object
#  4   address         59 non-null     object
#  5   city            59 non-null     object
#  6   state           30 non-null     object
#  7   country         59 non-null     object
#  8   postal_code     55 non-null     object
#  9   phone           58 non-null     object
#  10  fax             12 non-null     object
#  11  email           59 non-null     object
#  12  support_rep_id  59 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.1+ KB

# %%
df_customer.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_customer = df_customer.drop(df_customer[['company', 'state', 'fax']], axis=1)
df_customer.head()
# Out:
#    customer_id first_name    last_name                          address  \
# 0            1       Luís    Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 1            2     Leonie       Köhler          Theodor-Heuss-Straße 34
# 2            3   François     Tremblay                1498 rue Bélanger
# 3            4      Bjørn       Hansen                 Ullevålsveien 14
# 4            5  František  Wichterlová                    Klanova 9/506
#
#                   city         country postal_code               phone  \
# 0  São José dos Campos          Brazil   12227-000  +55 (12) 3923-5555
# 1            Stuttgart         Germany       70174    +49 0711 2842222
# 2             Montréal          Canada     H2G 1A7   +1 (514) 721-4711
# 3                 Oslo          Norway        0171     +47 22 44 22 22
# 4               Prague  Czech Republic       14700    +420 2 4172 5555
#
#                       email  support_rep_id
# 0      luisg@embraer.com.br               3
# 1     leonekohler@surfeu.de               5
# 2       ftremblay@gmail.com               3
# 3     bjorn.hansen@yahoo.no               4
# 4  frantisekw@jetbrains.com               4

# %%
df_customer['full_name'] = df_customer['first_name'] + ' ' + df_customer['last_name']
df_customer.head()
# Out:
#    customer_id first_name    last_name                          address  \
# 0            1       Luís    Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 1            2     Leonie       Köhler          Theodor-Heuss-Straße 34
# 2            3   François     Tremblay                1498 rue Bélanger
# 3            4      Bjørn       Hansen                 Ullevålsveien 14
# 4            5  František  Wichterlová                    Klanova 9/506
#
#                   city         country postal_code               phone  \
# 0  São José dos Campos          Brazil   12227-000  +55 (12) 3923-5555
# 1            Stuttgart         Germany       70174    +49 0711 2842222
# 2             Montréal          Canada     H2G 1A7   +1 (514) 721-4711
# 3                 Oslo          Norway        0171     +47 22 44 22 22
# 4               Prague  Czech Republic       14700    +420 2 4172 5555
#
#                       email  support_rep_id              full_name
# 0      luisg@embraer.com.br               3         Luís Gonçalves
# 1     leonekohler@surfeu.de               5          Leonie Köhler
# 2       ftremblay@gmail.com               3      François Tremblay
# 3     bjorn.hansen@yahoo.no               4           Bjørn Hansen
# 4  frantisekw@jetbrains.com               4  František Wichterlová

# %%
df_customer = df_customer.drop(df_customer[['first_name', 'last_name']], axis=1)

# %%
df_customer.insert(1, 'full_name', df_customer.pop('full_name'))

# %%
df_customer.head()
# Out:
#    customer_id              full_name                          address  \
# 0            1         Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 1            2          Leonie Köhler          Theodor-Heuss-Straße 34
# 2            3      François Tremblay                1498 rue Bélanger
# 3            4           Bjørn Hansen                 Ullevålsveien 14
# 4            5  František Wichterlová                    Klanova 9/506
#
#                   city         country postal_code               phone  \
# 0  São José dos Campos          Brazil   12227-000  +55 (12) 3923-5555
# 1            Stuttgart         Germany       70174    +49 0711 2842222
# 2             Montréal          Canada     H2G 1A7   +1 (514) 721-4711
# 3                 Oslo          Norway        0171     +47 22 44 22 22
# 4               Prague  Czech Republic       14700    +420 2 4172 5555
#
#                       email  support_rep_id
# 0      luisg@embraer.com.br               3
# 1     leonekohler@surfeu.de               5
# 2       ftremblay@gmail.com               3
# 3     bjorn.hansen@yahoo.no               4
# 4  frantisekw@jetbrains.com               4

# %% [markdown]
# #### invoice

# %%
df_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   invoice_id           412 non-null    int64
#  1   customer_id          412 non-null    int64
#  2   invoice_date         412 non-null    datetime64[ns]
#  3   billing_address      412 non-null    object
#  4   billing_city         412 non-null    object
#  5   billing_state        210 non-null    object
#  6   billing_country      412 non-null    object
#  7   billing_postal_code  384 non-null    object
#  8   total                412 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 29.1+ KB

# %%
df_invoice.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_invoice = df_invoice.drop(df_invoice[['billing_state', 'billing_postal_code']], axis=1)
df_invoice.head()
# Out:
#    invoice_id  customer_id invoice_date          billing_address billing_city  \
# 0           1            2   2021-01-01  Theodor-Heuss-Straße 34    Stuttgart
# 1           2            4   2021-01-02         Ullevålsveien 14         Oslo
# 2           3            8   2021-01-03          Grétrystraat 63     Brussels
# 3           4           14   2021-01-06           8210 111 ST NW     Edmonton
# 4           5           23   2021-01-11          69 Salem Street       Boston
#
#   billing_country  total
# 0         Germany   1.98
# 1          Norway   3.96
# 2         Belgium   5.94
# 3          Canada   8.91
# 4             USA  13.86

# %% [markdown]
# #### invoice line

# %%
df_invoice_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_line_id  2240 non-null   int64
#  1   invoice_id       2240 non-null   int64
#  2   track_id         2240 non-null   int64
#  3   unit_price       2240 non-null   float64
#  4   quantity         2240 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 87.6 KB

# %%
df_invoice_line.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### track

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3503 entries, 0 to 3502
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_id       3503 non-null   int64
#  1   name           3503 non-null   object
#  2   album_id       3503 non-null   int64
#  3   media_type_id  3503 non-null   int64
#  4   genre_id       3503 non-null   int64
#  5   composer       2526 non-null   object
#  6   milliseconds   3503 non-null   int64
#  7   bytes          3503 non-null   int64
#  8   unit_price     3503 non-null   float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 246.4+ KB

# %%
df_track.isna().sum()
# Out:
# track_id           0
# name               0
# album_id           0
# media_type_id      0
# genre_id           0
# composer         977
# milliseconds       0
# bytes              0
# unit_price         0
# dtype: int64

# %%
df_track.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### genre

# %%
df_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genre_id  25 non-null     int64
#  1   name      25 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 532.0+ bytes

# %%
df_genre.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### album

# %%
df_album.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   album_id   347 non-null    int64
#  1   title      347 non-null    object
#  2   artist_id  347 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.3+ KB

# %%
df_album.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### combine track

# %%
df_track = df_track.merge(df_genre, how='left', on='genre_id')
df_track
# Out:
#       track_id                                             name_x  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price      name_y
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
# [3503 rows x 10 columns]

# %%
df_track = df_track.rename(columns={'name_x': 'song_name', 'name_y': 'genre_name'})
df_track
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price  genre_name
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
# [3503 rows x 10 columns]

# %%
df_track = df_track.merge(df_album, how='left', on='album_id')
df_track
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price  genre_name  \
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
#                                                   title  artist_id
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Restless and Wild          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3498                             Respighi:Pines of Rome        226
# 3499  Schubert: The Late String Quartets & String Qu...        272
# 3500                                Monteverdi: L'Orfeo        273
# 3501                              Mozart: Chamber Music        274
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
# [3503 rows x 12 columns]

# %%
df_track = df_track.merge(df_artist, how='left', on='artist_id')
df_track
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price  genre_name  \
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
#                                                   title  artist_id  \
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Restless and Wild          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3498                             Respighi:Pines of Rome        226
# 3499  Schubert: The Late String Quartets & String Qu...        272
# 3500                                Monteverdi: L'Orfeo        273
# 3501                              Mozart: Chamber Music        274
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
#                                                    name
# 0                                                 AC/DC
# 1                                                Accept
# 2                                                Accept
# 3                                                Accept
# 4                                                Accept
# ...                                                 ...
# 3498                                     Eugene Ormandy
# 3499                             Emerson String Quartet
# 3500  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 3501                                      Nash Ensemble
# 3502                              Philip Glass Ensemble
#
# [3503 rows x 13 columns]

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3503 entries, 0 to 3502
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_id       3503 non-null   int64
#  1   song_name      3503 non-null   object
#  2   album_id       3503 non-null   int64
#  3   media_type_id  3503 non-null   int64
#  4   genre_id       3503 non-null   int64
#  5   composer       2526 non-null   object
#  6   milliseconds   3503 non-null   int64
#  7   bytes          3503 non-null   int64
#  8   unit_price     3503 non-null   float64
#  9   genre_name     3503 non-null   object
#  10  title          3503 non-null   object
#  11  artist_id      3503 non-null   int64
#  12  name           3503 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 355.9+ KB

# %%
df_track = df_track.rename(columns={'name': 'artist_name'})

# %%
df_track
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                               None        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price  genre_name  \
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
#                                                   title  artist_id  \
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Restless and Wild          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3498                             Respighi:Pines of Rome        226
# 3499  Schubert: The Late String Quartets & String Qu...        272
# 3500                                Monteverdi: L'Orfeo        273
# 3501                              Mozart: Chamber Music        274
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
#                                             artist_name
# 0                                                 AC/DC
# 1                                                Accept
# 2                                                Accept
# 3                                                Accept
# 4                                                Accept
# ...                                                 ...
# 3498                                     Eugene Ormandy
# 3499                             Emerson String Quartet
# 3500  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 3501                                      Nash Ensemble
# 3502                              Philip Glass Ensemble
#
# [3503 rows x 13 columns]

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3503 entries, 0 to 3502
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_id       3503 non-null   int64
#  1   song_name      3503 non-null   object
#  2   album_id       3503 non-null   int64
#  3   media_type_id  3503 non-null   int64
#  4   genre_id       3503 non-null   int64
#  5   composer       2526 non-null   object
#  6   milliseconds   3503 non-null   int64
#  7   bytes          3503 non-null   int64
#  8   unit_price     3503 non-null   float64
#  9   genre_name     3503 non-null   object
#  10  title          3503 non-null   object
#  11  artist_id      3503 non-null   int64
#  12  artist_name    3503 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 355.9+ KB

# %%
df_track['composer'] = df_track['composer'].fillna(df_track['artist_name'])
df_track
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3498              2        24
# 3499              2        24
# 3500              2        24
# 3501              2        24
# 3502              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4                            Deaffy & R.A. Smith-Diesel        375418
# ...                                                 ...           ...
# 3498                                     Eugene Ormandy        286741
# 3499                                     Franz Schubert        139200
# 3500                                 Claudio Monteverdi         66639
# 3501                            Wolfgang Amadeus Mozart        221331
# 3502                                       Philip Glass        206005
#
#          bytes  unit_price  genre_name  \
# 0     11170334        0.99        Rock
# 1      5510424        0.99        Rock
# 2      3990994        0.99        Rock
# 3      4331779        0.99        Rock
# 4      6290521        0.99        Rock
# ...        ...         ...         ...
# 3498   4718950        0.99   Classical
# 3499   2283131        0.99   Classical
# 3500   1189062        0.99   Classical
# 3501   3665114        0.99   Classical
# 3502   3305164        0.99  Soundtrack
#
#                                                   title  artist_id  \
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Restless and Wild          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3498                             Respighi:Pines of Rome        226
# 3499  Schubert: The Late String Quartets & String Qu...        272
# 3500                                Monteverdi: L'Orfeo        273
# 3501                              Mozart: Chamber Music        274
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
#                                             artist_name
# 0                                                 AC/DC
# 1                                                Accept
# 2                                                Accept
# 3                                                Accept
# 4                                                Accept
# ...                                                 ...
# 3498                                     Eugene Ormandy
# 3499                             Emerson String Quartet
# 3500  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 3501                                      Nash Ensemble
# 3502                              Philip Glass Ensemble
#
# [3503 rows x 13 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Menggabungkan tabel customer dan invoice untuk melihat performa pejualan per-customer menggunakan fungsi
# ```
# data_utama.merge(
#     data_yang_ingin_digabungkan,
#     how={‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’,
#     on='key'
# )
# ```

# %%
customer_invoice = df_customer.merge(df_invoice, how='left', on='customer_id')
customer_invoice
# Out:
#      customer_id        full_name                          address  \
# 0              1   Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 1              1   Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 2              1   Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 3              1   Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# 4              1   Luís Gonçalves  Av. Brigadeiro Faria Lima, 2170
# ..           ...              ...                              ...
# 407           59  Puja Srivastava                3,Raj Bhavan Road
# 408           59  Puja Srivastava                3,Raj Bhavan Road
# 409           59  Puja Srivastava                3,Raj Bhavan Road
# 410           59  Puja Srivastava                3,Raj Bhavan Road
# 411           59  Puja Srivastava                3,Raj Bhavan Road
#
#                     city country postal_code               phone  \
# 0    São José dos Campos  Brazil   12227-000  +55 (12) 3923-5555
# 1    São José dos Campos  Brazil   12227-000  +55 (12) 3923-5555
# 2    São José dos Campos  Brazil   12227-000  +55 (12) 3923-5555
# 3    São José dos Campos  Brazil   12227-000  +55 (12) 3923-5555
# 4    São José dos Campos  Brazil   12227-000  +55 (12) 3923-5555
# ..                   ...     ...         ...                 ...
# 407            Bangalore   India      560001    +91 080 22289999
# 408            Bangalore   India      560001    +91 080 22289999
# 409            Bangalore   India      560001    +91 080 22289999
# 410            Bangalore   India      560001    +91 080 22289999
# 411            Bangalore   India      560001    +91 080 22289999
#
#                         email  support_rep_id  invoice_id invoice_date  \
# 0        luisg@embraer.com.br               3          98   2022-03-11
# 1        luisg@embraer.com.br               3         121   2022-06-13
# 2        luisg@embraer.com.br               3         143   2022-09-15
# 3        luisg@embraer.com.br               3         195   2023-05-06
# 4        luisg@embraer.com.br               3         316   2024-10-27
# ..                        ...             ...         ...          ...
# 407  puja_srivastava@yahoo.in               3          45   2021-07-08
# 408  puja_srivastava@yahoo.in               3          97   2022-02-26
# 409  puja_srivastava@yahoo.in               3         218   2023-08-20
# 410  puja_srivastava@yahoo.in               3         229   2023-09-30
# 411  puja_srivastava@yahoo.in               3         284   2024-05-30
#
#                      billing_address         billing_city billing_country  \
# 0    Av. Brigadeiro Faria Lima, 2170  São José dos Campos          Brazil
# 1    Av. Brigadeiro Faria Lima, 2170  São José dos Campos          Brazil
# 2    Av. Brigadeiro Faria Lima, 2170  São José dos Campos          Brazil
# 3    Av. Brigadeiro Faria Lima, 2170  São José dos Campos          Brazil
# 4    Av. Brigadeiro Faria Lima, 2170  São José dos Campos          Brazil
# ..                               ...                  ...             ...
# 407                3,Raj Bhavan Road            Bangalore           India
# 408                3,Raj Bhavan Road            Bangalore           India
# 409                3,Raj Bhavan Road            Bangalore           India
# 410                3,Raj Bhavan Road            Bangalore           India
# 411                3,Raj Bhavan Road            Bangalore           India
#
#      total
# 0     3.98
# 1     3.96
# 2     5.94
# 3     0.99
# 4     1.98
# ..     ...
# 407   5.94
# 408   1.99
# 409   1.98
# 410  13.86
# 411   8.91
#
# [412 rows x 15 columns]

# %% [markdown]
# Fungsi ``` .describe() ``` adalah salah satu perintah pertama yang paling sering digunakan dalam proses Analisis Data Eksplorasi (EDA) dengan library pandas

# %%
customer_invoice.describe()
# Out:
#        customer_id  support_rep_id  invoice_id                   invoice_date  \
# count   412.000000      412.000000  412.000000                            412
# mean     29.929612        3.951456  206.500000  2023-06-26 08:05:49.514563072
# min       1.000000        3.000000    1.000000            2021-01-01 00:00:00
# 25%      15.000000        3.000000  103.750000            2022-03-27 00:00:00
# 50%      30.000000        4.000000  206.500000            2023-06-22 12:00:00
# 75%      45.000000        5.000000  309.250000            2024-09-26 06:00:00
# max      59.000000        5.000000  412.000000            2025-12-22 00:00:00
# std      17.010585        0.812058  119.078406                            NaN
#
#             total
# count  412.000000
# mean     5.651942
# min      0.990000
# 25%      1.980000
# 50%      3.960000
# 75%      8.910000
# max     25.860000
# std      4.745320

# %% [markdown]
# Secara sederhana, fungsi `.describe()` digunakan untuk menghasilkan ringkasan statistik deskriptif dari sebuah DataFrame atau kolom data. Ringkasan ini sangat berguna untuk mendapatkan gambaran umum tentang sebaran dan tendensi sentral dari data numerik Anda secara cepat.
#
# **Apa Saja yang Ditampilkan?**
#
# Ketika Anda menjalankan `df.describe()` pada DataFrame Anda, secara default ia akan menganalisis semua kolom yang berisi data numerik (angka) dan menampilkan:
#
# - `count`: Jumlah total data yang tidak kosong (non-null).
# - `mean`: Nilai rata-rata dari semua data di kolom tersebut.
# - `std`: Standar deviasi, yang mengukur seberapa tersebar data dari nilai rata-ratanya.
# - `min`: Nilai terkecil (minimum) dalam kolom.
# - `25%`: Kuartil pertama. Artinya, 25% data memiliki nilai di bawah angka ini.
# - `50%`: Median atau kuartil kedua. Ini adalah nilai tengah dari data. 50% data berada di bawah angka ini.
# - `75%`: Kuartil ketiga. Artinya, 75% data memiliki nilai di bawah angka ini.
# - `max`: Nilai terbesar (maksimum) dalam kolom.
#
# **Mengapa Ini Sangat Penting di EDA?**
#
# Deteksi Cepat Anomali: Anda bisa langsung melihat jika ada yang aneh. Misalnya, jika nilai ``max`` pada kolom umur adalah 200, berarti ada kesalahan input data.
#
# Memahami Distribusi Data: Dengan membandingkan `mean` (rata-rata) dan `50%` (median), Anda bisa mendapat petunjuk apakah distribusi data Anda simetris atau miring (skewed). Jika nilainya berdekatan, distribusinya cenderung simetris.
#
# Melihat Skala Data: Anda bisa melihat rentang nilai (`min` ke `max`) untuk setiap kolom, yang berguna untuk memahami skala dan variasi data.

# %%
monthly_revenue = customer_invoice.groupby(customer_invoice['invoice_date'].dt.to_period('M')).agg({'total': 'sum'}).reset_index()
# dt.to_period('M') berfungsi untuk mengubah tipe data datetime menjadi period bulanan
monthly_revenue['invoice_date'] = monthly_revenue['invoice_date'].astype(str)
# .astype(str) berfungsi untuk mengubah tipe data period menjadi string agar dapat divisualisasikan/di-plot
monthly_revenue
# Out:
#    invoice_date  total
# 0       2021-01  35.64
# 1       2021-02  37.62
# 2       2021-03  37.62
# 3       2021-04  37.62
# 4       2021-05  37.62
# 5       2021-06  37.62
# 6       2021-07  37.62
# 7       2021-08  37.62
# 8       2021-09  37.62
# 9       2021-10  37.62
# 10      2021-11  37.62
# 11      2021-12  37.62
# 12      2022-01  52.62
# 13      2022-02  46.62
# 14      2022-03  44.62
# 15      2022-04  37.62
# 16      2022-05  37.62
# 17      2022-06  37.62
# 18      2022-07  37.62
# 19      2022-08  37.62
# 20      2022-09  36.63
# 21      2022-10  37.62
# 22      2022-11  37.62
# 23      2022-12  37.62
# 24      2023-01  37.62
# 25      2023-02  37.62
# 26      2023-03  37.62
# 27      2023-04  51.62
# 28      2023-05  42.62
# 29      2023-06  50.62
# 30      2023-07  37.62
# 31      2023-08  37.62
# 32      2023-09  37.62
# 33      2023-10  37.62
# 34      2023-11  23.76
# 35      2023-12  37.62
# 36      2024-01  37.62
# 37      2024-02  37.62
# 38      2024-03  37.62
# 39      2024-04  37.62
# 40      2024-05  37.62
# 41      2024-06  37.62
# 42      2024-07  39.62
# 43      2024-08  47.62
# 44      2024-09  46.71
# 45      2024-10  42.62
# 46      2024-11  37.62
# 47      2024-12  37.62
# 48      2025-01  37.62
# 49      2025-02  27.72
# 50      2025-03  37.62
# 51      2025-04  33.66
# 52      2025-05  37.62
# 53      2025-06  37.62
# 54      2025-07  37.62
# 55      2025-08  37.62
# 56      2025-09  37.62
# 57      2025-10  37.62
# 58      2025-11  49.62
# 59      2025-12  38.62

# %% [markdown]
# Visualisasi dibawah ini menggunakan library matplotlib dan seaborn
#
# **Matplotlib** adalah library "kakek buyut" untuk visualisasi data di Python. Ini adalah fondasi bagi banyak library visualisasi lainnya, termasuk Seaborn. Matplotlib sangat kuat dan memberikan kontrol penuh atas setiap elemen dalam plot (judul, sumbu, warna, ketebalan garis, dll).
#
# **Seaborn** adalah library visualisasi yang dibangun di atas Matplotlib. Tujuannya adalah untuk membuat visualisasi statistik yang menarik dan informatif menjadi lebih mudah. Seaborn hadir dengan tema default yang lebih modern dan fungsi-fungsi yang dirancang khusus untuk analisis data.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_revenue, x='invoice_date', y='total', marker='o')
plt.title('Monthly Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.grid()
plt.show()

# %% [markdown]
# Linechart atau `lineplot` digunakan untuk menunjukkan tren atau perubahan data dari waktu ke waktu atau interval berkelanjutan lainnya.

# %%
plot = px.line(
    monthly_revenue, 
    x='invoice_date', 
    y='total', 
    title='Monthly Revenue Over Time', 
    labels={'invoice_date': 'Month',
             'total': 'Total Revenue'
    })
plot.update_layout(width=800, height=400)
plot.show()

# %% [markdown]
# Nah, visualisasi yang lebih interaktif di atas menggunakan pustaka **plotly**.
#
# Plotly adalah library yang dirancang khusus untuk membuat visualisasi data yang interaktif. Interaktivitas adalah Kunci: Ini adalah keunggulan terbesar Plotly. Grafik yang Anda buat bisa di-zoom, digeser (pan), dan saat Anda mengarahkan kursor ke titik data, akan muncul informasi detail (hover). Ini sangat berguna untuk eksplorasi data yang mendalam.
#
# **Plotly Express (`px`)**: Sama seperti Seaborn yang menyederhanakan Matplotlib, Plotly memiliki Plotly Express (yang biasa disingkat `px`). Ini adalah antarmuka yang sangat mudah digunakan untuk membuat visualisasi Plotly yang kompleks dengan kode yang sangat singkat. Pada visualisasi di atas, linechart ditampilkan menggunakan `px.line()`.

# %% [markdown]
# ### Explore Penjualan By Customer

# %%
customer_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      412 non-null    int64
#  1   full_name        412 non-null    object
#  2   address          412 non-null    object
#  3   city             412 non-null    object
#  4   country          412 non-null    object
#  5   postal_code      384 non-null    object
#  6   phone            405 non-null    object
#  7   email            412 non-null    object
#  8   support_rep_id   412 non-null    int64
#  9   invoice_id       412 non-null    int64
#  10  invoice_date     412 non-null    datetime64[ns]
#  11  billing_address  412 non-null    object
#  12  billing_city     412 non-null    object
#  13  billing_country  412 non-null    object
#  14  total            412 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(10)
# memory usage: 48.4+ KB

# %% [markdown]
# #### TOP customer sepanjang waktu

# %% [markdown]
# Membuat agregasi data menggunakan `.groupby` dan `.agg` kemudian mengurutkan data tersebut untuk memperoleh TOP value menggunakan `.sort_values`

# %%
top_customer = customer_invoice.groupby('full_name').agg({
    'total': 'sum'
    }).sort_values(
        by='total', 
        ascending=False).head(10).reset_index()
top_customer
# Out:
#             full_name  total
# 0         Helena Holý  49.62
# 1  Richard Cunningham  47.62
# 2          Luis Rojas  46.62
# 3       Hugh O'Reilly  45.62
# 4     Ladislav Kovács  45.62
# 5     Fynn Zimmermann  43.62
# 6       Frank Ralston  43.62
# 7       Julia Barnett  43.62
# 8       Astrid Gruber  42.62
# 9      Victor Stevens  42.62

# %% [markdown]
# parameter `sum` berfungsi untuk menjumlahkan data numerik

# %%
# QUEST 1
#TODO : gunakan .describe() untuk melihat ringkasan statistik dari data top customer
# Tulis kode di bawah ini

top_customer.describe()
# Out:
#            total
# count  10.000000
# mean   45.120000
# std     2.321398
# min    42.620000
# 25%    43.620000
# 50%    44.620000
# 75%    46.370000
# max    49.620000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_customer, 
    x='total',
    y='full_name',
)
plt.title('Top 10 Customers by Total Spending')
plt.xlabel('Total Spending')
plt.ylabel('Customer Name')
plt.show()

# %%
plot_top_customer = px.bar(
    top_customer.sort_values('total', ascending=True),
    x='total',
    y='full_name',
    title='Top 10 Customers by Total Spending',
    labels={'full_name': 'Customer Name', 'total': 'Total Spending'},
    orientation='h',
    color='total',
)
plot_top_customer.update_layout(width=800, height=400)
plot_top_customer

# %% [markdown]
# #### TOP customer 2023 - 2024

# %% [markdown]
# Membuat filter rentang waktu

# %%
periode_start = '2023-01-01'
periode_end = '2024-12-31'
periode_filer = (df_invoice['invoice_date'] >= periode_start) & (df_invoice['invoice_date'] <= periode_end)

# %%
periode_filer
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 407    False
# 408    False
# 409    False
# 410    False
# 411    False
# Name: invoice_date, Length: 412, dtype: bool

# %%
# QUEST : 2
# TODO gunakan .describe() untuk melihat ringkasan statistik dari data customer_invoice pada periode 2023-2024
customer_invoice[periode_filer].describe() # tambahkan .describe() di akhir untuk melihat ringkasan statistik
# Out:
#        customer_id  support_rep_id  invoice_id                   invoice_date  \
# count   166.000000      166.000000  166.000000                            166
# mean     36.072289        3.837349  208.656627  2023-07-05 21:49:52.771084288
# min      24.000000        3.000000    6.000000            2021-01-19 00:00:00
# 25%      30.000000        3.000000  105.250000            2022-04-11 00:00:00
# 50%      36.000000        4.000000  203.500000            2023-06-19 00:00:00
# 75%      42.000000        5.000000  311.750000            2024-09-30 06:00:00
# max      48.000000        5.000000  411.000000            2025-12-14 00:00:00
# std       6.876897        0.826121  120.034980                            NaN
#
#             total
# count  166.000000
# mean     5.680964
# min      0.990000
# 25%      1.980000
# 50%      3.960000
# 75%      8.910000
# max     23.860000
# std      4.898383

# %%
# QUEST : 3
# TODO lengkapilah kode berikut untuk mengagregasi total spending per customer pada periode 2023-2024 dan menampilkan 10 customer dengan total spending tertinggi

top_customer_2324 = customer_invoice[periode_filer].groupby('full_name').agg({
    # TODO: Hitung total spending per customer
    'total' : 'sum'
    }).sort_values(
        # TODO: Urutkan data berdasarkan total
        by='total', # lengkapi petik ini, 
        ascending=False).head(10).reset_index()
top_customer_2324
# Out:
#             full_name  total
# 0  Richard Cunningham  47.62
# 1     Ladislav Kovács  45.62
# 2       Hugh O'Reilly  45.62
# 3     Fynn Zimmermann  43.62
# 4       Julia Barnett  43.62
# 5      Victor Stevens  42.62
# 6    Terhi Hämäläinen  41.62
# 7    Isabelle Mercier  40.62
# 8      João Fernandes  39.62
# 9        Wyatt Girard  39.62

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_customer_2324,
    x='total',
    y='full_name',
    palette='viridis'
)
plt.title('Top 10 Customers by Total Spending (2023-2024)')
plt.xlabel('Total Spending')
plt.ylabel('Customer Name')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\4240194659.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
plot_top_customer_2324 = px.bar(
    top_customer_2324.sort_values('total', ascending=True),
    x='total',
    y='full_name',
    title='Top 10 Customers by Total Spending (2023-2024)',
    labels={'full_name': 'Customer Name', 'total': 'Total Spending'},
    orientation='h',
    color='total',
)
plot_top_customer_2324.update_layout(width=800, height=400)
plot_top_customer_2324.show()

# %% [markdown]
# ### Explore Penjualan By Country

# %% [markdown]
# #### TOP penjualan berdasarkan negara sepanjang waktu

# %%
# QUEST 4
# TODO : lengkapilah kode berikut untuk mengagregasi total spending per country dan menampilkan 10 country dengan total spending tertinggi
top_country = customer_invoice.groupby('country').agg({ # lengkapi petik di sini
    # TODO: Hitung total spending per country
    'total': 'sum'
    }).sort_values(
        by='total',
        ascending=False).reset_index() # urutkan negara berdasarkan total spending tertinggi
top_country
# Out:
#            country   total
# 0              USA  523.06
# 1           Canada  303.96
# 2           France  195.10
# 3           Brazil  190.10
# 4          Germany  156.48
# 5   United Kingdom  112.86
# 6   Czech Republic   90.24
# 7         Portugal   77.24
# 8            India   75.26
# 9            Chile   46.62
# 10         Ireland   45.62
# 11         Hungary   45.62
# 12         Austria   42.62
# 13         Finland   41.62
# 14     Netherlands   40.62
# 15          Norway   39.62
# 16          Sweden   38.62
# 17           Italy   37.62
# 18       Argentina   37.62
# 19       Australia   37.62
# 20         Denmark   37.62
# 21         Belgium   37.62
# 22          Poland   37.62
# 23           Spain   37.62

# %%
# QUEST 5
# TODO : buatlah visualisasi menggunakan barplot untuk menampilkan 10 country dengan total spending tertinggi

plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_country,
    x='total', # isi x dengan total
    y='country', # isi y dengan country
    palette='viridis'
)
plt.title('Top 10 Countries by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Country')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\1882005329.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
top_country_plot = px.bar(
    top_country.sort_values('total', ascending=True),
    x='total',
    y='country',
    title='Top 10 Countries by Total Sales',
    labels={'country': 'Country', 'total': 'Total Sales'},
    orientation='h',
    color='total',
)
top_country_plot.update_layout(width=800, height=400)
top_country_plot.show()

# %% [markdown]
# `px.bar()` digunakan untuk membuat barplot

# %%
plot_top_country_map = px.scatter_geo(
    top_country,
    locations='country',
    locationmode='country names',
    color='total',
    hover_name='country',
    size='total',
    projection='natural earth',
    title='Top 10 Countries by Total Sales (2023-2024)',
    color_continuous_scale=px.colors.sequential.Plasma
)
plot_top_country_map.update_layout(width=800, height=400)
plot_top_country_map.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\2057499759.py:1: DeprecationWarning:
#
# The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.

# %% [markdown]
# Visualisasi di atas menggunakan `px.scatter_geo()` untuk memvisualisasikan sebaran di peta dunia yang interaktif.
#
# - `top_country` : dataframe yang digunakan
# - `locations` : lokasi yang akan ditampilkan di peta
# - `locationmode='country names'` : Memberi tahu Plotly bahwa data di kolom 'country' adalah nama negara (misalnya, "USA", "Indonesia"), bukan kode negara (seperti "USA", "IDN").
# - `color='total'` : Warna setiap titik di peta akan ditentukan oleh nilai pada kolom 'total'. Semakin tinggi total penjualan, semakin cerah/berbeda warnanya.
# - `hover_name` : membuat interaksi hover
# - `size='total'` : Ukuran setiap titik di peta juga akan ditentukan oleh nilai pada kolom 'total'. Negara dengan penjualan lebih besar akan memiliki titik yang lebih besar.
# - `projection='natural earth'` : Memilih jenis proyeksi peta agar terlihat lebih natural.
# - `color_continuous_scale=...Plasma` : Mengatur skema warna yang akan digunakan. Plasma adalah salah satu palet warna bawaan dari Plotly.

# %% [markdown]
# #### TOP Penjualan berdasarkan Negara 2023 - 2024

# %%
# QUEST 6
# TODO perbaiki filter pada kode berikut
top_country_2324 = customer_invoice.groupby('country').agg({ # kode ini kemungkinan salah, perbaikilah
    'total': 'sum'
    }).sort_values(
        by='total', 
        ascending=False).head(10).reset_index()
top_country_2324
# Out:
#           country   total
# 0             USA  523.06
# 1          Canada  303.96
# 2          France  195.10
# 3          Brazil  190.10
# 4         Germany  156.48
# 5  United Kingdom  112.86
# 6  Czech Republic   90.24
# 7        Portugal   77.24
# 8           India   75.26
# 9           Chile   46.62

# %%
# QUEST 7
# TODO buatlah visualisasi menggunakan barplot untuk menampilkan 10 country dengan total spending pada periode 2023-2024
plot_top_country_2324 = px.bar(
    top_country_2324.sort_values('total', ascending=True),
    # TODO lengkapi kode di bawah ini
    x='total',
    y='country',
    title='Top 10 Countries by Total Sales (2023-2024)',
    labels={'country': 'Country', 'total': 'Total Sales'},
    orientation='h',
)
plot_top_country_2324.update_layout(width=800, height=400)
plot_top_country_2324.show()

# %%
plot_top_country_2324_map = px.scatter_geo(
    top_country_2324,
    locations='country',
    locationmode='country names',
    color='total',
    hover_name='country',
    size='total',
    projection='natural earth',
    title='Top 10 Countries by Total Sales (2023-2024)',
    color_continuous_scale=px.colors.sequential.Plasma
)
plot_top_country_2324_map.update_layout(width=800, height=400)
plot_top_country_2324_map.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\394494553.py:1: DeprecationWarning:
#
# The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.

# %% [markdown]
# ### Explore performa penjualan

# %% [markdown]
# #### Persentase penjualan sepanjang waktu

# %% [markdown]
# Menghitung total revenue

# %%
total_revenue = customer_invoice['total'].sum()
total_revenue
# Out:
# np.float64(2328.6)

# %% [markdown]
# Mengetahui total spending per customer

# %%
spending_per_customer = customer_invoice.groupby('full_name').agg({
    'total': 'sum'
}).reset_index()
spending_per_customer
# Out:
#                 full_name  total
# 0          Aaron Mitchell  37.62
# 1         Alexandre Rocha  37.62
# 2           Astrid Gruber  42.62
# 3            Bjørn Hansen  39.62
# 4         Camille Bernard  38.62
# 5            Daan Peeters  37.62
# 6              Dan Miller  39.62
# 7         Diego Gutiérrez  37.62
# 8      Dominique Lefebvre  38.62
# 9         Eduardo Martins  37.62
# 10         Edward Francis  37.62
# 11         Ellie Sullivan  37.62
# 12             Emma Jones  37.62
# 13          Enrique Muñoz  37.62
# 14         Fernanda Ramos  37.62
# 15           Frank Harris  37.62
# 16          Frank Ralston  43.62
# 17  František Wichterlová  40.62
# 18      François Tremblay  39.62
# 19        Fynn Zimmermann  43.62
# 20       Hannah Schneider  37.62
# 21        Heather Leacock  39.62
# 22            Helena Holý  49.62
# 23          Hugh O'Reilly  45.62
# 24       Isabelle Mercier  40.62
# 25             Jack Smith  39.62
# 26      Jennifer Peterson  38.62
# 27       Joakim Johansson  38.62
# 28  Johannes Van der Berg  40.62
# 29            John Gordon  37.62
# 30         João Fernandes  39.62
# 31          Julia Barnett  43.62
# 32           Kara Nielsen  37.62
# 33            Kathy Chase  37.62
# 34        Ladislav Kovács  45.62
# 35          Leonie Köhler  37.62
# 36          Lucas Mancini  37.62
# 37             Luis Rojas  46.62
# 38         Luís Gonçalves  39.62
# 39       Madalena Sampaio  37.62
# 40           Manoj Pareek  38.62
# 41            Marc Dubois  37.62
# 42           Mark Philips  37.62
# 43            Mark Taylor  37.62
# 44            Martha Silk  37.62
# 45        Michelle Brooks  37.62
# 46        Niklas Schröder  37.62
# 47           Patrick Gray  37.62
# 48            Phil Hughes  37.62
# 49        Puja Srivastava  36.64
# 50     Richard Cunningham  47.62
# 51           Robert Brown  37.62
# 52        Roberto Almeida  37.62
# 53       Stanisław Wójcik  37.62
# 54           Steve Murray  37.62
# 55       Terhi Hämäläinen  41.62
# 56              Tim Goyer  38.62
# 57         Victor Stevens  42.62
# 58           Wyatt Girard  39.62

# %%
# QUEST 8
# TODO gunakan .describe() untuk melihat ringkasan statistik dari data spending_per_customer
spending_per_customer.describe()
# Out:
#            total
# count  59.000000
# mean   39.467797
# std     2.911078
# min    36.640000
# 25%    37.620000
# 50%    37.620000
# 75%    39.620000
# max    49.620000

# %% [markdown]
# Mengetahui persentase kontribusi pembelian customer terhadap total pendapatan

# %%
spending_per_customer['percentage_of_total'] = (spending_per_customer['total'] / total_revenue) * 100
spending_per_customer.sort_values('percentage_of_total', ascending=False)
# Out:
#                 full_name  total  percentage_of_total
# 22            Helena Holý  49.62             2.130894
# 50     Richard Cunningham  47.62             2.045006
# 37             Luis Rojas  46.62             2.002061
# 23          Hugh O'Reilly  45.62             1.959117
# 34        Ladislav Kovács  45.62             1.959117
# 19        Fynn Zimmermann  43.62             1.873229
# 16          Frank Ralston  43.62             1.873229
# 31          Julia Barnett  43.62             1.873229
# 2           Astrid Gruber  42.62             1.830284
# 57         Victor Stevens  42.62             1.830284
# 55       Terhi Hämäläinen  41.62             1.787340
# 17  František Wichterlová  40.62             1.744396
# 24       Isabelle Mercier  40.62             1.744396
# 28  Johannes Van der Berg  40.62             1.744396
# 38         Luís Gonçalves  39.62             1.701452
# 25             Jack Smith  39.62             1.701452
# 21        Heather Leacock  39.62             1.701452
# 30         João Fernandes  39.62             1.701452
# 58           Wyatt Girard  39.62             1.701452
# 18      François Tremblay  39.62             1.701452
# 3            Bjørn Hansen  39.62             1.701452
# 6              Dan Miller  39.62             1.701452
# 4         Camille Bernard  38.62             1.658507
# 27       Joakim Johansson  38.62             1.658507
# 56              Tim Goyer  38.62             1.658507
# 8      Dominique Lefebvre  38.62             1.658507
# 26      Jennifer Peterson  38.62             1.658507
# 40           Manoj Pareek  38.62             1.658507
# 13          Enrique Muñoz  37.62             1.615563
# 12             Emma Jones  37.62             1.615563
# 11         Ellie Sullivan  37.62             1.615563
# 20       Hannah Schneider  37.62             1.615563
# 15           Frank Harris  37.62             1.615563
# 9         Eduardo Martins  37.62             1.615563
# 10         Edward Francis  37.62             1.615563
# 5            Daan Peeters  37.62             1.615563
# 7         Diego Gutiérrez  37.62             1.615563
# 1         Alexandre Rocha  37.62             1.615563
# 0          Aaron Mitchell  37.62             1.615563
# 14         Fernanda Ramos  37.62             1.615563
# 33            Kathy Chase  37.62             1.615563
# 29            John Gordon  37.62             1.615563
# 32           Kara Nielsen  37.62             1.615563
# 42           Mark Philips  37.62             1.615563
# 41            Marc Dubois  37.62             1.615563
# 39       Madalena Sampaio  37.62             1.615563
# 35          Leonie Köhler  37.62             1.615563
# 36          Lucas Mancini  37.62             1.615563
# 43            Mark Taylor  37.62             1.615563
# 45        Michelle Brooks  37.62             1.615563
# 44            Martha Silk  37.62             1.615563
# 54           Steve Murray  37.62             1.615563
# 48            Phil Hughes  37.62             1.615563
# 47           Patrick Gray  37.62             1.615563
# 46        Niklas Schröder  37.62             1.615563
# 52        Roberto Almeida  37.62             1.615563
# 53       Stanisław Wójcik  37.62             1.615563
# 51           Robert Brown  37.62             1.615563
# 49        Puja Srivastava  36.64             1.573478

# %% [markdown]
# #### Persentase penjualan 2023 - 2024

# %%
# QUEST 9 
# TODO : hitung total revenue pada periode 2023-2024
total_revenue_2324 = customer_invoice['invoice_date'].dt.year.isin([2023,2024]) # lengkapi blok ini
total_revenue_2324
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 407    False
# 408    False
# 409     True
# 410     True
# 411     True
# Name: invoice_date, Length: 412, dtype: bool

# %%
# QUEST 10
# TODO : hitung persentase kontribusi pembelian customer terhadap total pendapatan pada periode 2023-2024
spending_per_customer_2324 = customer_invoice[total_revenue_2324].groupby('full_name').agg({
    'total': 'sum'
}).reset_index()
spending_per_customer_2324['percentage_of_total'] = (spending_per_customer_2324['total'] / total_revenue_2324 *  100) # kali seratus
spending_per_customer_2324.sort_values('percentage_of_total', ascending=False)
# Out:
#                 full_name  total  percentage_of_total
# 0          Aaron Mitchell  11.88                  inf
# 1         Alexandre Rocha  11.88                  inf
# 2           Astrid Gruber  11.88                  inf
# 6              Dan Miller  16.85                  inf
# 9         Eduardo Martins  10.89                  inf
# 8      Dominique Lefebvre  13.87                  inf
# 7         Diego Gutiérrez   0.99                  inf
# 23          Hugh O'Reilly  32.75                  inf
# 16          Frank Ralston  15.88                  inf
# 15           Frank Harris  10.89                  inf
# 14         Fernanda Ramos  24.75                  inf
# 22            Helena Holý  12.87                  inf
# 21        Heather Leacock  18.83                  inf
# 20       Hannah Schneider  12.87                  inf
# 19        Fynn Zimmermann  16.89                  inf
# 50     Richard Cunningham  26.83                  inf
# 56              Tim Goyer  13.87                  inf
# 57         Victor Stevens  29.75                  inf
# 40           Manoj Pareek  10.89                  inf
# 35          Leonie Köhler  12.87                  inf
# 42           Mark Philips   6.93                  inf
# 41            Marc Dubois  14.85                  inf
# 34        Ladislav Kovács  11.88                  inf
# 30         João Fernandes  26.75                  inf
# 29            John Gordon  12.87                  inf
# 28  Johannes Van der Berg  13.89                  inf
# 27       Joakim Johansson  24.75                  inf
# 58           Wyatt Girard  26.75                  inf
# 55       Terhi Hämäläinen  16.87                  inf
# 54           Steve Murray   8.91                  inf
# 43            Mark Taylor  24.75                  inf
# 48            Phil Hughes  11.88                  inf
# 49        Puja Srivastava  24.75                  inf
# 44            Martha Silk  10.89                  inf
# 25             Jack Smith  26.75               2675.0
# 3            Bjørn Hansen  26.75               2675.0
# 5            Daan Peeters  24.75               2475.0
# 33            Kathy Chase  24.75               2475.0
# 46        Niklas Schröder  24.75               2475.0
# 51           Robert Brown  24.75               2475.0
# 13          Enrique Muñoz  22.77               2277.0
# 17  František Wichterlová  19.83               1983.0
# 24       Isabelle Mercier  19.83               1983.0
# 31          Julia Barnett  17.88               1788.0
# 38         Luís Gonçalves  16.83               1683.0
# 36          Lucas Mancini  15.84               1584.0
# 32           Kara Nielsen  15.84               1584.0
# 10         Edward Francis  15.84               1584.0
# 26      Jennifer Peterson  12.87               1287.0
# 47           Patrick Gray  12.87               1287.0
# 37             Luis Rojas  12.87               1287.0
# 53       Stanisław Wójcik  11.88               1188.0
# 52        Roberto Almeida   8.91                891.0
# 11         Ellie Sullivan   8.91                891.0
# 12             Emma Jones   6.93                693.0
# 39       Madalena Sampaio   6.93                693.0
# 18      François Tremblay   5.94                594.0
# 4         Camille Bernard   3.97                397.0
# 45        Michelle Brooks   2.97                297.0

# %% [markdown]
# ### Explore Penjualan by Track (Genre)

# %%
track_popularity = df_track.merge(
    df_invoice_line, 
    how='left',
    left_on='track_id',
    right_on='track_id'
)
track_popularity
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            2                                  Balls to the Wall         2
# 3            3                                    Fast As a Shark         3
# 4            4                                  Restless and Wild         3
# ...        ...                                                ...       ...
# 3754      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3755      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3756      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3757      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3758      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3754              2        24
# 3755              2        24
# 3756              2        24
# 3757              2        24
# 3758              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 3     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 4     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# ...                                                 ...           ...
# 3754                                     Franz Schubert        139200
# 3755                                     Franz Schubert        139200
# 3756                                 Claudio Monteverdi         66639
# 3757                            Wolfgang Amadeus Mozart        221331
# 3758                                       Philip Glass        206005
#
#          bytes  unit_price_x  genre_name  \
# 0     11170334          0.99        Rock
# 1      5510424          0.99        Rock
# 2      5510424          0.99        Rock
# 3      3990994          0.99        Rock
# 4      4331779          0.99        Rock
# ...        ...           ...         ...
# 3754   2283131          0.99   Classical
# 3755   2283131          0.99   Classical
# 3756   1189062          0.99   Classical
# 3757   3665114          0.99   Classical
# 3758   3305164          0.99  Soundtrack
#
#                                                   title  artist_id  \
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Balls to the Wall          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3754  Schubert: The Late String Quartets & String Qu...        272
# 3755  Schubert: The Late String Quartets & String Qu...        272
# 3756                                Monteverdi: L'Orfeo        273
# 3757                              Mozart: Chamber Music        274
# 3758  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
#                                             artist_name  invoice_line_id  \
# 0                                                 AC/DC            579.0
# 1                                                Accept              1.0
# 2                                                Accept           1154.0
# 3                                                Accept           1728.0
# 4                                                Accept              2.0
# ...                                                 ...              ...
# 3754                             Emerson String Quartet            578.0
# 3755                             Emerson String Quartet           1727.0
# 3756  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...              NaN
# 3757                                      Nash Ensemble              NaN
# 3758                              Philip Glass Ensemble              NaN
#
#       invoice_id  unit_price_y  quantity
# 0          108.0          0.99       1.0
# 1            1.0          0.99       1.0
# 2          214.0          0.99       1.0
# 3          319.0          0.99       1.0
# 4            1.0          0.99       1.0
# ...          ...           ...       ...
# 3754       108.0          0.99       1.0
# 3755       319.0          0.99       1.0
# 3756         NaN           NaN       NaN
# 3757         NaN           NaN       NaN
# 3758         NaN           NaN       NaN
#
# [3759 rows x 17 columns]

# %%
# QUEST 11
# TODO : gabungkan data track_popularity dengan df_invoice untuk mendapatkan informasi invoice_date dan customer
track_popularity = track_popularity.merge(
    # TODO lengkapi kode berikut
    df_invoice[['total','invoice_id', 'invoice_date', 'customer_id']],
    how='left',
    left_on='invoice_id',
    right_on='invoice_id'
)
track_popularity
# Out:
#       track_id                                          song_name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            2                                  Balls to the Wall         2
# 3            3                                    Fast As a Shark         3
# 4            4                                  Restless and Wild         3
# ...        ...                                                ...       ...
# 3754      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3755      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3756      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3757      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3758      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# 0                 1         1
# 1                 2         1
# 2                 2         1
# 3                 2         1
# 4                 2         1
# ...             ...       ...
# 3754              2        24
# 3755              2        24
# 3756              2        24
# 3757              2        24
# 3758              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 2     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 3     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 4     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# ...                                                 ...           ...
# 3754                                     Franz Schubert        139200
# 3755                                     Franz Schubert        139200
# 3756                                 Claudio Monteverdi         66639
# 3757                            Wolfgang Amadeus Mozart        221331
# 3758                                       Philip Glass        206005
#
#          bytes  unit_price_x  genre_name  \
# 0     11170334          0.99        Rock
# 1      5510424          0.99        Rock
# 2      5510424          0.99        Rock
# 3      3990994          0.99        Rock
# 4      4331779          0.99        Rock
# ...        ...           ...         ...
# 3754   2283131          0.99   Classical
# 3755   2283131          0.99   Classical
# 3756   1189062          0.99   Classical
# 3757   3665114          0.99   Classical
# 3758   3305164          0.99  Soundtrack
#
#                                                   title  artist_id  \
# 0                 For Those About To Rock We Salute You          1
# 1                                     Balls to the Wall          2
# 2                                     Balls to the Wall          2
# 3                                     Restless and Wild          2
# 4                                     Restless and Wild          2
# ...                                                 ...        ...
# 3754  Schubert: The Late String Quartets & String Qu...        272
# 3755  Schubert: The Late String Quartets & String Qu...        272
# 3756                                Monteverdi: L'Orfeo        273
# 3757                              Mozart: Chamber Music        274
# 3758  Koyaanisqatsi (Soundtrack from the Motion Pict...        275
#
#                                             artist_name  invoice_line_id  \
# 0                                                 AC/DC            579.0
# 1                                                Accept              1.0
# 2                                                Accept           1154.0
# 3                                                Accept           1728.0
# 4                                                Accept              2.0
# ...                                                 ...              ...
# 3754                             Emerson String Quartet            578.0
# 3755                             Emerson String Quartet           1727.0
# 3756  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...              NaN
# 3757                                      Nash Ensemble              NaN
# 3758                              Philip Glass Ensemble              NaN
#
#       invoice_id  unit_price_y  quantity  total invoice_date  customer_id
# 0          108.0          0.99       1.0   5.94   2022-04-13         47.0
# 1            1.0          0.99       1.0   1.98   2021-01-01          2.0
# 2          214.0          0.99       1.0   8.91   2023-07-25         33.0
# 3          319.0          0.99       1.0   8.91   2024-11-01         13.0
# 4            1.0          0.99       1.0   1.98   2021-01-01          2.0
# ...          ...           ...       ...    ...          ...          ...
# 3754       108.0          0.99       1.0   5.94   2022-04-13         47.0
# 3755       319.0          0.99       1.0   8.91   2024-11-01         13.0
# 3756         NaN           NaN       NaN    NaN          NaT          NaN
# 3757         NaN           NaN       NaN    NaN          NaT          NaN
# 3758         NaN           NaN       NaN    NaN          NaT          NaN
#
# [3759 rows x 20 columns]

# %% [markdown]
# #### Genre Teratas (Quantity)

# %%
# QUEST 12
# TODO : buat agregasi/pivot table untuk mengetahui genre apa yang paling banyak terjual (quantity) dan memberikan kontribusi terbesar terhadap total revenue (total)
top_genre = pd.pivot_table(
    track_popularity,
    index='genre_name',
    values=['quantity', 'total'],
    aggfunc={'quantity': 'sum', 'total': 'sum'}
).reset_index()
top_genre
# Out:
#             genre_name  quantity    total
# 0          Alternative      14.0   211.17
# 1   Alternative & Punk     244.0  1961.66
# 2                Blues      61.0   429.66
# 3           Bossa Nova      15.0    86.13
# 4            Classical      41.0   317.04
# 5               Comedy       9.0   112.30
# 6                Drama      29.0   544.61
# 7       Easy Listening      10.0   138.60
# 8    Electronica/Dance      12.0   149.62
# 9          Heavy Metal      12.0   161.37
# 10         Hip Hop/Rap      17.0   166.41
# 11                Jazz      80.0   746.46
# 12               Latin     386.0  3472.55
# 13               Metal     264.0  2093.13
# 14               Opera       0.0     0.00
# 15                 Pop      28.0   239.75
# 16            R&B/Soul      41.0   338.62
# 17              Reggae      30.0   332.64
# 18                Rock     835.0  7720.02
# 19       Rock And Roll       6.0    83.16
# 20    Sci Fi & Fantasy      20.0   198.87
# 21     Science Fiction       6.0   102.41
# 22          Soundtrack      20.0   242.55
# 23            TV Shows      47.0   817.71
# 24               World      13.0   182.18

# %% [markdown]
# #### Genre Teratas (Total Revenue)

# %%
# QUEST 13
# TODO : urutkan data top_genre berdasarkan total revenue (total)
top_genre = top_genre.sort_values('total', ascending=False)
top_genre
# Out:
#             genre_name  quantity    total
# 18                Rock     835.0  7720.02
# 12               Latin     386.0  3472.55
# 13               Metal     264.0  2093.13
# 1   Alternative & Punk     244.0  1961.66
# 23            TV Shows      47.0   817.71
# 11                Jazz      80.0   746.46
# 6                Drama      29.0   544.61
# 2                Blues      61.0   429.66
# 16            R&B/Soul      41.0   338.62
# 17              Reggae      30.0   332.64
# 4            Classical      41.0   317.04
# 22          Soundtrack      20.0   242.55
# 15                 Pop      28.0   239.75
# 0          Alternative      14.0   211.17
# 20    Sci Fi & Fantasy      20.0   198.87
# 24               World      13.0   182.18
# 10         Hip Hop/Rap      17.0   166.41
# 9          Heavy Metal      12.0   161.37
# 8    Electronica/Dance      12.0   149.62
# 7       Easy Listening      10.0   138.60
# 5               Comedy       9.0   112.30
# 21     Science Fiction       6.0   102.41
# 3           Bossa Nova      15.0    86.13
# 19       Rock And Roll       6.0    83.16
# 14               Opera       0.0     0.00

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
sns.barplot(
    data=top_genre.sort_values(by='quantity', ascending=False).head(5),
    x='quantity',
    y='genre_name',
    palette='viridis',
    ax=ax[0]
)
ax[0].set_title('Top 5 Genres by Quantity Sold')
ax[0].set_xlabel('Quantity Sold')
ax[0].set_ylabel('Genre')

sns.barplot(
    data=top_genre.sort_values(by='total', ascending=False).head(5),
    x='total',
    y='genre_name',
    palette='viridis',
    ax=ax[1]
)
ax[1].set_title('Top 5 Genres by Total Sales')
ax[1].set_xlabel('Total Sales')
ax[1].set_ylabel('Genre')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\952730418.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\952730418.py:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
fig = make_subplots(rows=1, cols=2, subplot_titles=('Top Genre by Quantity', 'Top Genre by Sales'))
fig.add_trace(
    go.Bar(
        x=top_genre.head(5).sort_values(by='quantity', ascending=True)['quantity'],
        y=top_genre.head(5).sort_values(by='quantity', ascending=True)['genre_name'],
        orientation='h',
        marker_color='skyblue',
        name='Quantity'
    ),
    row=1, col=1
)

fig.add_trace(
    go.Bar(
        x=top_genre.head(5).sort_values(by='total', ascending=True)['total'],
        y=top_genre.head(5).sort_values(by='total', ascending=True)['genre_name'],
        orientation='h',
        # marker_color='skyblue',
        name='Total Sales'
    ),
    row=1, col=2
)

fig.update_layout(height=500, width=1000, showlegend=False)
fig.update_xaxes(title_text="Quantity", row=1, col=1)
fig.update_xaxes(title_text="Revenue", row=1, col=2)
fig.update_yaxes(title_text="Genre", row=1, col=1)
fig.update_yaxes(title_text="Genre", row=1, col=2)
fig.show()

# %% [markdown]
# #### TOP genre 2023 - 2024 (triwulan)

# %%
track_popularity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3759 entries, 0 to 3758
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   track_id         3759 non-null   int64
#  1   song_name        3759 non-null   object
#  2   album_id         3759 non-null   int64
#  3   media_type_id    3759 non-null   int64
#  4   genre_id         3759 non-null   int64
#  5   composer         3759 non-null   object
#  6   milliseconds     3759 non-null   int64
#  7   bytes            3759 non-null   int64
#  8   unit_price_x     3759 non-null   float64
#  9   genre_name       3759 non-null   object
#  10  title            3759 non-null   object
#  11  artist_id        3759 non-null   int64
#  12  artist_name      3759 non-null   object
#  13  invoice_line_id  2240 non-null   float64
#  14  invoice_id       2240 non-null   float64
#  15  unit_price_y     2240 non-null   float64
#  16  quantity         2240 non-null   float64
#  17  total            2240 non-null   float64
#  18  invoice_date     2240 non-null   datetime64[ns]
#  19  customer_id      2240 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(7), object(5)
# memory usage: 587.5+ KB

# %%
periode_start = '2023-01-01'
periode_end = '2024-12-31'

track_popularity_2324 = track_popularity[
    (track_popularity['invoice_date'] >= periode_start) &
    (track_popularity['invoice_date'] <= periode_end)
]
track_popularity_2324
# Out:
#       track_id                                          song_name  album_id  \
# 2            2                                  Balls to the Wall         2
# 3            3                                    Fast As a Shark         3
# 9            8                                   Inject The Venom         1
# 11           9                                         Snowballed         1
# 16          14                                         Spellbound         1
# ...        ...                                                ...       ...
# 3743      3489                Symphony No. 2: III. Allegro vivace       334
# 3747      3493                           Metopes, Op. 29: Calypso       337
# 3748      3494  Symphony No. 2, Op. 16 -  "The Four Temperamen...       338
# 3753      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3755      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
#
#       media_type_id  genre_id  \
# 2                 2         1
# 3                 2         1
# 9                 1         1
# 11                1         1
# 16                1         1
# ...             ...       ...
# 3743              2        24
# 3747              2        24
# 3748              2        24
# 3753              2        24
# 3755              2        24
#
#                                                composer  milliseconds  \
# 2     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 3     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 9             Angus Young, Malcolm Young, Brian Johnson        210834
# 11            Angus Young, Malcolm Young, Brian Johnson        203102
# 16            Angus Young, Malcolm Young, Brian Johnson        270863
# ...                                                 ...           ...
# 3743                                         Kurt Weill        376510
# 3747                                  Karol Szymanowski        333669
# 3748                                       Carl Nielsen        286998
# 3753                                     Eugene Ormandy        286741
# 3755                                     Franz Schubert        139200
#
#         bytes  unit_price_x genre_name  \
# 2     5510424          0.99       Rock
# 3     3990994          0.99       Rock
# 9     6852860          0.99       Rock
# 11    6599424          0.99       Rock
# 16    8817038          0.99       Rock
# ...       ...           ...        ...
# 3743  6129146          0.99  Classical
# 3747  5548755          0.99  Classical
# 3748  4834785          0.99  Classical
# 3753  4718950          0.99  Classical
# 3755  2283131          0.99  Classical
#
#                                                   title  artist_id  \
# 2                                     Balls to the Wall          2
# 3                                     Restless and Wild          2
# 9                 For Those About To Rock We Salute You          1
# 11                For Those About To Rock We Salute You          1
# 16                For Those About To Rock We Salute You          1
# ...                                                 ...        ...
# 3743                       Weill: The Seven Deadly Sins        264
# 3747                   Szymanowski: Piano Works, Vol. 1        266
# 3748                        Nielsen: The Six Symphonies        267
# 3753                             Respighi:Pines of Rome        226
# 3755  Schubert: The Late String Quartets & String Qu...        272
#
#                                        artist_name  invoice_line_id  \
# 2                                           Accept           1154.0
# 3                                           Accept           1728.0
# 9                                            AC/DC           1155.0
# 11                                           AC/DC           1729.0
# 16                                           AC/DC           1156.0
# ...                                            ...              ...
# 3743  Kent Nagano and Orchestre de l'Opéra de Lyon           1151.0
# 3747                                 Martin Roscoe           1152.0
# 3748            Göteborgs Symfoniker & Neeme Järvi           1726.0
# 3753                                Eugene Ormandy           1153.0
# 3755                        Emerson String Quartet           1727.0
#
#       invoice_id  unit_price_y  quantity  total invoice_date  customer_id
# 2          214.0          0.99       1.0   8.91   2023-07-25         33.0
# 3          319.0          0.99       1.0   8.91   2024-11-01         13.0
# 9          214.0          0.99       1.0   8.91   2023-07-25         33.0
# 11         319.0          0.99       1.0   8.91   2024-11-01         13.0
# 16         214.0          0.99       1.0   8.91   2023-07-25         33.0
# ...          ...           ...       ...    ...          ...          ...
# 3743       213.0          0.99       1.0   5.94   2023-07-22         27.0
# 3747       213.0          0.99       1.0   5.94   2023-07-22         27.0
# 3748       319.0          0.99       1.0   8.91   2024-11-01         13.0
# 3753       214.0          0.99       1.0   8.91   2023-07-25         33.0
# 3755       319.0          0.99       1.0   8.91   2024-11-01         13.0
#
# [889 rows x 20 columns]

# %% [markdown]
# `.dt.to_period('Q')` berguna untuk mengelompokkan data berdasarkan quarter atau triwulan

# %%
track_popularity_2324['quarter'] = track_popularity_2324['invoice_date'].dt.to_period('Q')
track_popularity_2324
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\305548186.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       track_id                                          song_name  album_id  \
# 2            2                                  Balls to the Wall         2
# 3            3                                    Fast As a Shark         3
# 9            8                                   Inject The Venom         1
# 11           9                                         Snowballed         1
# 16          14                                         Spellbound         1
# ...        ...                                                ...       ...
# 3743      3489                Symphony No. 2: III. Allegro vivace       334
# 3747      3493                           Metopes, Op. 29: Calypso       337
# 3748      3494  Symphony No. 2, Op. 16 -  "The Four Temperamen...       338
# 3753      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3755      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
#
#       media_type_id  genre_id  \
# 2                 2         1
# 3                 2         1
# 9                 1         1
# 11                1         1
# 16                1         1
# ...             ...       ...
# 3743              2        24
# 3747              2        24
# 3748              2        24
# 3753              2        24
# 3755              2        24
#
#                                                composer  milliseconds  \
# 2     U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...        342562
# 3     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 9             Angus Young, Malcolm Young, Brian Johnson        210834
# 11            Angus Young, Malcolm Young, Brian Johnson        203102
# 16            Angus Young, Malcolm Young, Brian Johnson        270863
# ...                                                 ...           ...
# 3743                                         Kurt Weill        376510
# 3747                                  Karol Szymanowski        333669
# 3748                                       Carl Nielsen        286998
# 3753                                     Eugene Ormandy        286741
# 3755                                     Franz Schubert        139200
#
#         bytes  unit_price_x genre_name  ... artist_id  \
# 2     5510424          0.99       Rock  ...         2
# 3     3990994          0.99       Rock  ...         2
# 9     6852860          0.99       Rock  ...         1
# 11    6599424          0.99       Rock  ...         1
# 16    8817038          0.99       Rock  ...         1
# ...       ...           ...        ...  ...       ...
# 3743  6129146          0.99  Classical  ...       264
# 3747  5548755          0.99  Classical  ...       266
# 3748  4834785          0.99  Classical  ...       267
# 3753  4718950          0.99  Classical  ...       226
# 3755  2283131          0.99  Classical  ...       272
#
#                                        artist_name invoice_line_id  \
# 2                                           Accept          1154.0
# 3                                           Accept          1728.0
# 9                                            AC/DC          1155.0
# 11                                           AC/DC          1729.0
# 16                                           AC/DC          1156.0
# ...                                            ...             ...
# 3743  Kent Nagano and Orchestre de l'Opéra de Lyon          1151.0
# 3747                                 Martin Roscoe          1152.0
# 3748            Göteborgs Symfoniker & Neeme Järvi          1726.0
# 3753                                Eugene Ormandy          1153.0
# 3755                        Emerson String Quartet          1727.0
#
#       invoice_id  unit_price_y  quantity  total  invoice_date customer_id  \
# 2          214.0          0.99       1.0   8.91    2023-07-25        33.0
# 3          319.0          0.99       1.0   8.91    2024-11-01        13.0
# 9          214.0          0.99       1.0   8.91    2023-07-25        33.0
# 11         319.0          0.99       1.0   8.91    2024-11-01        13.0
# 16         214.0          0.99       1.0   8.91    2023-07-25        33.0
# ...          ...           ...       ...    ...           ...         ...
# 3743       213.0          0.99       1.0   5.94    2023-07-22        27.0
# 3747       213.0          0.99       1.0   5.94    2023-07-22        27.0
# 3748       319.0          0.99       1.0   8.91    2024-11-01        13.0
# 3753       214.0          0.99       1.0   8.91    2023-07-25        33.0
# 3755       319.0          0.99       1.0   8.91    2024-11-01        13.0
#
#       quarter
# 2      2023Q3
# 3      2024Q4
# 9      2023Q3
# 11     2024Q4
# 16     2023Q3
# ...       ...
# 3743   2023Q3
# 3747   2023Q3
# 3748   2024Q4
# 3753   2023Q3
# 3755   2024Q4
#
# [889 rows x 21 columns]

# %%
# QUEST 14
# TODO : buat agregasi/pivot table untuk mengetahui genre apa yang paling banyak terjual (quantity) dan memberikan kontribusi terbesar terhadap total revenue (total) pada periode 2023-2024, kemudian kelompokkan berdasarkan quarter
genre_quarter = track_popularity_2324.groupby([
    # TODO lengkapi kode di bawah ini
    'genre_name',
    'quarter'
    ]).agg({
    'quantity': 'sum',
    'total': 'sum'
}).reset_index()
genre_quarter
# Out:
#             genre_name quarter  quantity   total
# 0          Alternative  2023Q2       4.0   63.44
# 1          Alternative  2024Q4       4.0   67.44
# 2   Alternative & Punk  2023Q1      21.0  200.97
# 3   Alternative & Punk  2023Q2       8.0   74.43
# 4   Alternative & Punk  2023Q3       6.0   68.31
# ..                 ...     ...       ...     ...
# 88            TV Shows  2024Q3      11.0  134.12
# 89            TV Shows  2024Q4       2.0   27.77
# 90               World  2023Q2       1.0   15.86
# 91               World  2024Q1       2.0   27.72
# 92               World  2024Q2       1.0   13.86
#
# [93 rows x 4 columns]

# %%
genre_quarter['quarter'] = genre_quarter['quarter'].astype(str)

plt.figure(figsize=(16, 8))
sns.lineplot(
    data=genre_quarter, 
    x='quarter', 
    y='total', 
    hue='genre_name'
)
plt.title('Total Revenue per Genre per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
# plt.tight_layout()
plt.show()

# %%
plot_genre_quarter_2324 = px.line(
    genre_quarter,
    x='quarter',
    y='total',
    color='genre_name',
    title='Genre Sales Trend 2023 - 2024'
)
plot_genre_quarter_2324.update_layout(width=800, height=400)
plot_genre_quarter_2324.show()

# %%
genre_quarter['quarter'] = genre_quarter['quarter'].astype(str)

plt.figure(figsize=(16, 8))
sns.lineplot(
    data=genre_quarter, 
    x='quarter', 
    y='quantity', 
    hue='genre_name'
)
plt.title('Total Quantity per Genre per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Quantity')
# plt.tight_layout()
plt.show()

# %%
plot_genre_quarter_2324 = px.line(
    genre_quarter,
    x='quarter',
    y='quantity',
    color='genre_name',
    title='Genre Quantity Trend 2023 - 2024'
)
plot_genre_quarter_2324.update_layout(width=800, height=400)
plot_genre_quarter_2324.show()

# %% [markdown]
# ### Explore Penjualan by Track (Artist)

# %%
# QUEST 15
# TODO : buat agregasi/pivot table untuk mengetahui artist apa yang paling banyak terjual (quantity) dan memberikan kontribusi terbesar terhadap total revenue (total)
top_artist = track_popularity.groupby('artist_name').agg({
    # TODO lengkapi kode di bawah ini
    'quantity': 'sum',
    'total': 'sum'
}).reset_index()
top_artist
# Out:
#                                            artist_name  quantity   total
# 0                                                AC/DC      16.0  107.91
# 1            Aaron Copland & London Symphony Orchestra       0.0    0.00
# 2                                       Aaron Goldberg       0.0    0.00
# 3    Academy of St. Martin in the Fields & Sir Nevi...       1.0    1.98
# 4    Academy of St. Martin in the Fields Chamber En...       0.0    0.00
# ..                                                 ...       ...     ...
# 199                                 Vinícius De Moraes       6.0  104.16
# 200                                     Wilhelm Kempff       0.0    0.00
# 201                                     Yehudi Menuhin       1.0    1.98
# 202                                           Yo-Yo Ma       1.0   16.86
# 203                                     Zeca Pagodinho       9.0  161.74
#
# [204 rows x 3 columns]

# %%
track_popularity.describe()
# Out:
#           track_id     album_id  media_type_id     genre_id  milliseconds  \
# count  3759.000000  3759.000000    3759.000000  3759.000000  3.759000e+03
# mean   1745.795158   140.512104       1.202980     5.650705  3.884790e+05
# min       1.000000     1.000000       1.000000     1.000000  1.071000e+03
# 25%     874.500000    70.000000       1.000000     1.000000  2.066935e+05
# 50%    1746.000000   141.000000       1.000000     3.000000  2.555290e+05
# 75%    2615.500000   211.000000       1.000000     7.000000  3.210575e+05
# max    3503.000000   347.000000       5.000000    25.000000  5.286953e+06
# std    1008.467630    81.597803       0.571201     6.119668  5.249629e+05
#
#               bytes  unit_price_x    artist_id  invoice_line_id   invoice_id  \
# count  3.759000e+03   3759.000000  3759.000000      2240.000000  2240.000000
# mean   3.257527e+07      1.048792    93.651503      1120.500000   206.868750
# min    3.874700e+04      0.990000     1.000000         1.000000     1.000000
# 25%    6.329877e+06      0.990000    52.000000       560.750000   103.000000
# 50%    8.101979e+06      0.990000    90.000000      1120.500000   207.000000
# 75%    1.023119e+07      0.990000   134.000000      1680.250000   311.000000
# max    1.059546e+09      1.990000   275.000000      2240.000000   412.000000
# std    1.033811e+08      0.235267    53.489698       646.776623   119.134877
#
#        unit_price_y  quantity        total                   invoice_date  \
# count   2240.000000    2240.0  2240.000000                           2240
# mean       1.039554       1.0     9.307420  2023-06-25 13:42:12.857142784
# min        0.990000       1.0     0.990000            2021-01-01 00:00:00
# 25%        0.990000       1.0     5.940000            2022-03-21 00:00:00
# 50%        0.990000       1.0     8.910000            2023-06-24 00:00:00
# 75%        0.990000       1.0    13.860000            2024-09-28 00:00:00
# max        1.990000       1.0    25.860000            2025-12-22 00:00:00
# std        0.217069       0.0     5.115131                            NaN
#
#        customer_id
# count  2240.000000
# mean     29.974107
# min       1.000000
# 25%      15.000000
# 50%      30.000000
# 75%      45.000000
# max      59.000000
# std      17.018715

# %% [markdown]
# #### Artis Teratas (Quantity)

# %%
# QUEST 16
# TODO urutkan data top_artist berdasarkan quantity
top_artist = top_artist.sort_values('quantity', ascending=False)
top_artist
# Out:
#                                            artist_name  quantity    total
# 91                                         Iron Maiden     140.0  1233.54
# 194                                                 U2     107.0   895.59
# 125                                          Metallica      91.0   599.94
# 107                                       Led Zeppelin      87.0   620.73
# 142                            Os Paralamas Do Sucesso      45.0   265.32
# ..                                                 ...       ...      ...
# 150                              Philip Glass Ensemble       0.0     0.00
# 140  Orchestre Révolutionnaire et Romantique & John...       0.0     0.00
# 166                 Sergei Prokofiev & Yuri Temirkanov       0.0     0.00
# 192                                        Ton Koopman       0.0     0.00
# 200                                     Wilhelm Kempff       0.0     0.00
#
# [204 rows x 3 columns]

# %% [markdown]
# #### Artis Teratas (Total Revenue)

# %%
# QUEST 17
# TODO urutkan data top_artist berdasarkan total
top_artist = top_artist.sort_values('total', ascending=False)
top_artist
# Out:
#                                            artist_name  quantity    total
# 91                                         Iron Maiden     140.0  1233.54
# 194                                                 U2     107.0   895.59
# 113                                               Lost      41.0   833.70
# 107                                       Led Zeppelin      87.0   620.73
# 125                                          Metallica      91.0   599.94
# ..                                                 ...       ...      ...
# 150                              Philip Glass Ensemble       0.0     0.00
# 140  Orchestre Révolutionnaire et Romantique & John...       0.0     0.00
# 166                 Sergei Prokofiev & Yuri Temirkanov       0.0     0.00
# 192                                        Ton Koopman       0.0     0.00
# 200                                     Wilhelm Kempff       0.0     0.00
#
# [204 rows x 3 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
sns.barplot(
    data=top_artist.sort_values(by='quantity', ascending=False).head(10),
    x='quantity',
    y='artist_name',
    ax=ax[0],
    palette='viridis'
)
sns.barplot(
    data=top_artist.sort_values(by='total', ascending=False).head(10),
    x='total',
    y='artist_name',
    ax=ax[1],
    palette='viridis'
)
ax[0].set_title('Top 10 Artists by Quantity Sold')
ax[0].set_xlabel('Quantity Sold')
ax[0].set_ylabel('Artist')
ax[1].set_title('Top 10 Artists by Total Sales')
ax[1].set_xlabel('Total Sales')
ax[1].set_ylabel('Artist')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\232910430.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\232910430.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
top5_quantity = top_artist.sort_values(by='quantity', ascending=False).head(5).sort_values(by='quantity', ascending=True)
top5_total = top_artist.sort_values(by='total', ascending=False).head(5).sort_values(by='total', ascending=True)

fig = make_subplots(rows=1, cols=2, subplot_titles=('Top Artists by Quantity', 'Top Artists by Sales'))

fig.add_trace(
    go.Bar(
        x=top5_quantity['quantity'],
        y=top5_quantity['artist_name'],
        orientation='h',
        marker_color='skyblue',
        name='Quantity'
    ),
    row=1, col=1
)

fig.add_trace(
    go.Bar(
        x=top5_total['total'],
        y=top5_total['artist_name'],
        orientation='h',
        marker_color='orange',
        name='Total Sales'
    ),
    row=1, col=2
)

fig.update_layout(height=500, width=1000, showlegend=False)
fig.update_xaxes(title_text="Quantity", row=1, col=1)
fig.update_xaxes(title_text="Revenue", row=1, col=2)
fig.update_yaxes(title_text="Artist", row=1, col=1)
fig.update_yaxes(title_text="Artist", row=1, col=2)
fig.show()
# ...existing code...

# %% [markdown]
# #### TOP artist 2023 - 2024 (triwulan)

# %%
# QUEST 18
# TODO buat agregasi/pivot table untuk mengetahui artist apa yang paling banyak terjual (quantity) dan memberikan kontribusi terbesar terhadap total revenue (total) pada periode 2023-2024, kemudian kelompokkan berdasarkan quarter
artist_quarter = track_popularity_2324.groupby([
    # TODO lengkapi kode di bawah ini
    'quarter',
    'artist_name']).agg({
    'quantity': 'sum',
    'total': 'sum'
}).reset_index()
artist_quarter
# Out:
#     quarter              artist_name  quantity  total
# 0    2023Q1            Lenny Kravitz       3.0  41.58
# 1    2023Q1  Os Paralamas Do Sucesso      12.0  42.57
# 2    2023Q1            Ozzy Osbourne       4.0  26.73
# 3    2023Q1             Page & Plant       2.0  17.82
# 4    2023Q1               Passengers       3.0  26.73
# ..      ...                      ...       ...    ...
# 249  2024Q4        Temple of the Dog       1.0  16.86
# 250  2024Q4               The Posies       1.0  16.86
# 251  2024Q4                       U2       4.0  43.64
# 252  2024Q4          Various Artists       4.0  55.44
# 253  2024Q4                 Yo-Yo Ma       1.0  16.86
#
# [254 rows x 4 columns]

# %%
artist_quarter['quarter'] = artist_quarter['quarter'].astype(str)

plt.figure(figsize=(16, 8))
sns.lineplot(
    data=artist_quarter, 
    x='quarter', 
    y='total', 
    hue='artist_name'
)
plt.title('Total Revenue per Artist per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
plt.show()

# %%
# QUEST 19
# TODO lengkapi kode untuk membuat visualisasi menggunakan line plot berikut
plot_artist_quarter_2324 = px.line(
    # TODO lengkapi kode di bawah ini
    artist_quarter,
    x='quarter',
    y='quantity',
    color='artist_name',
    title='Artist Quantity Trend 2023 - 2024'
)
plot_artist_quarter_2324.update_layout(width=1200, height=400)
plot_artist_quarter_2324.show()

# %% [markdown]
# ### Explore support rep

# %% [markdown]
# #### support rep by country

# %%
support_rep = customer_invoice.groupby(['support_rep_id', 'country']).agg({
    'customer_id': 'count',
}).reset_index()
support_rep
# Out:
#     support_rep_id         country  customer_id
# 0                3          Brazil           14
# 1                3          Canada           35
# 2                3         Finland            7
# 3                3          France           14
# 4                3         Germany           14
# 5                3         Hungary            7
# 6                3           India           13
# 7                3         Ireland            7
# 8                3             USA           21
# 9                3  United Kingdom           14
# 10               4       Argentina            7
# 11               4       Australia            7
# 12               4         Belgium            7
# 13               4          Brazil           14
# 14               4          Canada            7
# 15               4  Czech Republic            7
# 16               4         Denmark            7
# 17               4          France           14
# 18               4          Norway            7
# 19               4          Poland            7
# 20               4        Portugal           14
# 21               4             USA           42
# 22               5         Austria            7
# 23               5          Brazil            7
# 24               5          Canada           14
# 25               5           Chile            7
# 26               5  Czech Republic            7
# 27               5          France            7
# 28               5         Germany           14
# 29               5           Italy            7
# 30               5     Netherlands            7
# 31               5           Spain            7
# 32               5          Sweden            7
# 33               5             USA           28
# 34               5  United Kingdom            7

# %%
plot_suport_rep = px.scatter_geo(
    support_rep,
    locations='country',
    locationmode='country names',
    color='customer_id',
    hover_name='country',
    size='customer_id',
    projection='natural earth',
    title='Support Rep by Country',
    color_continuous_scale=px.colors.sequential.Plasma
)
plot_suport_rep.update_layout(width=800, height=400)
plot_suport_rep.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\3748238058.py:1: DeprecationWarning:
#
# The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.

# %% [markdown]
# #### support rep by city

# %%
support_rep = customer_invoice.groupby(['support_rep_id', 'city', 'country']).agg({
    'customer_id': 'count',
}).reset_index()
support_rep
# Out:
#     support_rep_id                 city         country  customer_id
# 0                3            Bangalore           India            6
# 1                3               Berlin         Germany            7
# 2                3             Bordeaux          France            7
# 3                3             Budapest         Hungary            7
# 4                3              Chicago             USA            7
# 5                3            Cupertino             USA            7
# 6                3                Delhi           India            7
# 7                3                Dijon          France            7
# 8                3               Dublin         Ireland            7
# 9                3            Frankfurt         Germany            7
# 10               3             Helsinki         Finland            7
# 11               3               London  United Kingdom           14
# 12               3             Montréal          Canada            7
# 13               3             New York             USA            7
# 14               3               Ottawa          Canada            7
# 15               3       Rio de Janeiro          Brazil            7
# 16               3  São José dos Campos          Brazil            7
# 17               3              Toronto          Canada            7
# 18               3            Vancouver          Canada            7
# 19               3          Yellowknife          Canada            7
# 20               4               Boston             USA            7
# 21               4             Brasília          Brazil            7
# 22               4             Brussels         Belgium            7
# 23               4         Buenos Aires       Argentina            7
# 24               4           Copenhagen         Denmark            7
# 25               4           Fort Worth             USA            7
# 26               4               Lisbon        Portugal            7
# 27               4        Mountain View             USA           14
# 28               4              Orlando             USA            7
# 29               4                 Oslo          Norway            7
# 30               4                Paris          France           14
# 31               4                Porto        Portugal            7
# 32               4               Prague  Czech Republic            7
# 33               4               Sidney       Australia            7
# 34               4            São Paulo          Brazil            7
# 35               4               Tucson             USA            7
# 36               4               Warsaw          Poland            7
# 37               4             Winnipeg          Canada            7
# 38               5            Amsterdam     Netherlands            7
# 39               5               Berlin         Germany            7
# 40               5            Edinburgh  United Kingdom            7
# 41               5             Edmonton          Canada            7
# 42               5              Halifax          Canada            7
# 43               5                 Lyon          France            7
# 44               5              Madison             USA            7
# 45               5               Madrid           Spain            7
# 46               5               Prague  Czech Republic            7
# 47               5              Redmond             USA            7
# 48               5                 Reno             USA            7
# 49               5                 Rome           Italy            7
# 50               5       Salt Lake City             USA            7
# 51               5             Santiago           Chile            7
# 52               5            Stockholm          Sweden            7
# 53               5            Stuttgart         Germany            7
# 54               5            São Paulo          Brazil            7
# 55               5               Vienne         Austria            7

# %%
plot_suport_rep = px.scatter_geo(
    support_rep,
    locations='country',
    locationmode='country names',
    color='customer_id',
    hover_name='city',
    size='customer_id',
    projection='natural earth',
    title='Support Rep by City (World Map)',
    color_continuous_scale=px.colors.sequential.Plasma,
    scope='world'
)
plot_suport_rep.update_layout(width=900, height=500)
plot_suport_rep.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2088\1028433882.py:1: DeprecationWarning:
#
# The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.

# %% [markdown]
# ### Your Turn!
#
# Lakukan EDA pada data lain yang kalian gunakan

# %%
# QUEST 20
# TODO : Lengkapi EDA kalian sendiri di bawah ini
#Mengelola trend customer berdasarkan invoice date dan total spending
customer_trend = customer_invoice.groupby(['customer_id', 'invoice_date']).agg({
    'total': 'sum'
}).reset_index()

# gabungkan dengan nama customer
customer_trend = customer_trend.merge(
    df_customer[['customer_id', 'full_name']],
    on='customer_id',
    how='left'
)

customer_line = px.line(
    customer_trend,
    x='invoice_date',
    y='total',
    color='full_name',
    title='Customer Spending Trend Over Time'
)
customer_line.update_layout(width=1200, height=400)
customer_line.show()

# %% [markdown]
# ## Kesimpulan
#
# 1. 10 pelanggan dengan total belanja tertinggi secara keseluruhan. Berdasarkan analisis negara, USA, Kanada, Brazil, Prancis, dan Jerman adalah pasar terbesar. Sangat mungkin 10 pelanggan teratas ini berasal dari negara-negara tersebut, menjadikan mereka target bernilai tinggi.
# 2. Data dengan sangat jelas menunjukkan adanya peluang signifikan untuk meningkatkan pendapatan melalui promosi yang ditargetkan. Preferensi pelanggan sangat terkonsentrasi pada genre Rock dan Metal, yang diperkuat oleh daftar artis terlaris seperti Iron Maiden, U2, Led Zeppelin, dan Metallica. Selain itu, teridentifikasi adanya pola penjualan musiman yang dapat diprediksi, di mana pendapatan secara konsisten memuncak pada Kuartal 4 dan Kuartal 1. Dengan demikian, strategi yang paling efektif adalah memfokuskan kampanye pemasaran pada artis dan genre terkuat ini selama periode puncak penjualan di akhir dan awal tahun.
# 3. Peta menunjukkan bahwa konsentrasi pelanggan terbesar yang ditangani oleh tim support berada di Amerika Utara (khususnya USA dan Kanada) dan Eropa (khususnya Inggris, Jerman, dan Prancis). Titik-titik di peta yang lebih besar dan lebih berwarna terkonsentrasi di wilayah ini.
